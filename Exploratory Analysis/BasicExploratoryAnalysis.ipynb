# %%
import pandas as pd
from pandas import Series,DataFrame
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
pd.core.common.is_list_like = pd.api.types.is_list_like
import pandas_datareader as web
from datetime import datetime
from __future__ import division

# %%
AAPL = pd.read_csv('AAPL.csv')
AMZN =  pd.read_csv('AMZN.csv')
FB = pd.read_csv('FB.csv')
GOOG =  pd.read_csv('GOOG.csv')
NFLX = pd.read_csv('NFLX.csv')
TSLA = pd.read_csv('TSLA.csv')

# %%
AAPL.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2020-03-25  62.687500  64.562500  61.075001  61.380001  60.907871
# 1  2020-03-26  61.630001  64.669998  61.590000  64.610001  64.113029
# 2  2020-03-27  63.187500  63.967499  61.762501  61.935001  61.458603
# 3  2020-03-30  62.685001  63.880001  62.349998  63.702499  63.212502
# 4  2020-03-31  63.900002  65.622498  63.000000  63.572498  63.083504
#
#       Volume
# 0  303602000
# 1  252087200
# 2  204216800
# 3  167976400
# 4  197002000

# %%
AMZN.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2020-03-25  1920.689941  1950.260010  1885.780029  1885.839966
# 1  2020-03-26  1902.000000  1956.489990  1889.290039  1955.489990
# 2  2020-03-27  1930.859985  1939.790039  1899.920044  1900.099976
# 3  2020-03-30  1922.829956  1973.630005  1912.339966  1963.949951
# 4  2020-03-31  1964.349976  1993.020020  1944.010010  1949.719971
#
#      Adj Close   Volume
# 0  1885.839966  6479100
# 1  1955.489990  6221300
# 2  1900.099976  5387900
# 3  1963.949951  6126100
# 4  1949.719971  5123600

# %%
GOOG.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2020-03-25  1126.469971  1148.900024  1086.010010  1102.489990
# 1  2020-03-26  1111.800049  1169.969971  1093.530029  1161.750000
# 2  2020-03-27  1125.670044  1150.670044  1105.910034  1110.709961
# 3  2020-03-30  1125.040039  1151.630005  1096.479980  1146.819946
# 4  2020-03-31  1147.300049  1175.310059  1138.140015  1162.810059
#
#      Adj Close   Volume
# 0  1102.489990  4081500
# 1  1161.750000  3571700
# 2  1110.709961  3208500
# 3  1146.819946  2574100
# 4  1162.810059  2486400

# %%
AAPL.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   107.600506  109.015744  106.022420  107.551875  107.234642
# std     22.148389   22.287415   21.634390   21.931690   22.054153
# min     60.084999   61.287498   59.224998   60.227501   59.764240
# 25%     89.711872   91.073126   88.146248   89.940624   89.490404
# 50%    115.255001  116.600003  113.615002  115.125000  114.830001
# 75%    124.122501  125.432499  121.914997  124.084999  123.975413
# max    143.600006  145.089996  141.369995  143.160004  142.946396
#
#              Volume
# count  2.520000e+02
# mean   1.388759e+08
# std    5.354327e+07
# min    4.669130e+07
# 25%    1.005924e+08
# 50%    1.264480e+08
# 75%    1.659367e+08
# max    3.743368e+08

# %%
AMZN.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count   252.000000   252.000000   252.000000   252.000000   252.000000
# mean   2962.324168  2999.529791  2920.381706  2960.141224  2960.141224
# std     393.226803   393.909976   384.644576   387.021919   387.021919
# min    1901.640015  1926.329956  1885.780029  1885.839966  1885.839966
# 25%    2688.775024  2747.760009  2673.522522  2708.582580  2708.582580
# 50%    3126.000000  3165.260010  3086.025024  3116.319946  3116.319946
# 75%    3209.017456  3247.117493  3165.572449  3205.317505  3205.317505
# max    3547.000000  3552.250000  3486.689941  3531.449951  3531.449951
#
#              Volume
# count  2.520000e+02
# mean   4.534236e+06
# std    1.588827e+06
# min    1.451900e+06
# 25%    3.306075e+06
# 50%    4.227950e+06
# 75%    5.384525e+06
# max    1.203820e+07

# %%
GOOG.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count   252.000000   252.000000   252.000000   252.000000   252.000000
# mean   1613.560300  1634.902564  1595.591407  1615.562359  1615.562359
# std     255.402393   257.790371   254.476510   255.636444   255.636444
# min    1098.260010  1123.540039  1079.810059  1097.880005  1097.880005
# 25%    1441.875000  1451.057525  1422.092468  1439.012482  1439.012482
# 50%    1554.425049  1576.165954  1529.922485  1557.690002  1557.690002
# 75%    1771.994964  1788.148712  1755.269989  1769.197510  1769.197510
# max    2119.270020  2152.679932  2104.360107  2128.310059  2128.310059
#
#              Volume
# count  2.520000e+02
# mean   1.757966e+06
# std    6.416374e+05
# min    3.468000e+05
# 25%    1.351650e+06
# 50%    1.605100e+06
# 75%    1.967450e+06
# max    4.329100e+06

# %%
TSLA.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   434.176485  445.062366  421.701492  434.456610  434.456610
# std    231.420135  235.877207  225.584535  231.347160  231.347160
# min     96.206001   98.851997   89.279999   90.893997   90.893997
# 25%    200.447506  203.642505  198.202003  200.683006  200.683006
# 50%    416.225006  427.884994  406.880004  418.695007  418.695007
# 75%    634.897506  652.205002  615.297485  640.732514  640.732514
# max    891.380005  900.400024  871.599976  883.090027  883.090027
#
#              Volume
# count  2.520000e+02
# mean   5.909473e+07
# std    3.156205e+07
# min    1.515770e+07
# 25%    3.495135e+07
# 50%    5.112020e+07
# 75%    7.914908e+07
# max    2.221262e+08

# %%
FB.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   249.931984  253.794644  246.163215  250.005754  250.005754
# std     33.408170   33.700618   33.001061   33.193057   33.193057
# min    157.149994  157.910004  150.830002  154.179993  154.179993
# 25%    234.404995  237.275002  231.107498  233.890003  233.890003
# 50%    261.524994  266.000000  258.520005  261.675004  261.675004
# 75%    272.665001  277.322495  268.874992  272.887497  272.887497
# max    300.160004  304.670013  293.049988  303.910004  303.910004
#
#              Volume
# count  2.520000e+02
# mean   2.247245e+07
# std    9.823011e+06
# min    6.702000e+06
# 25%    1.635390e+07
# 50%    2.044485e+07
# 75%    2.571278e+07
# max    7.634390e+07

# %%
NFLX.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean   486.869206  494.947221  478.594764  486.979167  486.979167
# std     49.118874   49.102068   48.064196   48.392214   48.392214
# min    344.000000  362.000000  339.170013  342.390015  342.390015
# 25%    454.187500  465.000008  449.602501  454.827507  454.827507
# 50%    493.639999  502.089996  484.794998  493.074997  493.074997
# 75%    519.952514  529.722489  512.547516  523.147491  523.147491
# max    582.450012  593.289978  570.400024  586.340027  586.340027
#
#              Volume
# count  2.520000e+02
# mean   6.288953e+06
# std    4.111012e+06
# min    1.144000e+06
# 25%    3.873675e+06
# 50%    5.350850e+06
# 75%    7.233200e+06
# max    3.263750e+07

# %%
AAPL['Close'].plot(legend=True, figsize = (12, 6))
plt.show()

# %%
AMZN['Close'].plot(legend=True, figsize = (12, 6))
plt.show()

# %%
GOOG['Close'].plot(legend=True, figsize = (12, 6))
plt.show()

# %%
FB['Close'].plot(legend=True, figsize = (12, 6))
plt.show()

# %%
NFLX['Close'].plot(legend=True, figsize = (12, 6))
plt.show()

# %%
TSLA['Close'].plot(legend=True, figsize = (12, 6))
plt.show()

# %%
AAPL['Volume'].plot(legend=True,figsize=(10,4))
plt.show()

# %%
AMZN['Volume'].plot(legend=True,figsize=(10,4))
plt.show()

# %%
FB['Volume'].plot(legend=True,figsize=(10,4))
plt.show()

# %%
GOOG['Volume'].plot(legend=True,figsize=(10,4))
plt.show()

# %%
NFLX['Volume'].plot(legend=True,figsize=(10,4))
plt.show()

# %%
TSLA['Volume'].plot(legend=True,figsize=(10,4))
plt.show()

# %%
AAPL['Open'].plot(legend=True,figsize=(10,4))
plt.show()

# %%
AMZN['Open'].plot(legend=True,figsize=(10,4))
plt.show()

# %%
GOOG['Open'].plot(legend=True,figsize=(10,4))
plt.show()

# %%
FB['Open'].plot(legend=True,figsize=(10,4))
plt.show()

# %%
TSLA['Open'].plot(legend=True,figsize=(10,4))
plt.show()

# %%
NFLX['Open'].plot(legend=True,figsize=(10,4))
plt.show()
