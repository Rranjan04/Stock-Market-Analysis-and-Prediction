# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from pandas.plotting import lag_plot
from pandas import datetime
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
import warnings
warnings.filterwarnings('ignore')
# Out:
# <ipython-input-33-1fc2c8d80e72>:5: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %%
AAPL = pd.read_csv('AAPL.csv')
AMZN =  pd.read_csv('AMZN.csv')
FB = pd.read_csv('FB.csv')
GOOG =  pd.read_csv('GOOG.csv')
NFLX = pd.read_csv('NFLX.csv')
TSLA = pd.read_csv('TSLA.csv')

# %% [markdown]
# #### Model parameters
# The standard ARIMA models expect as input parameters 3 arguments i.e. p,d,q.
# - p is the number of lag observations.
# - d is the degree of differencing.
# - q is the size/width of the moving average window.

# %% [markdown]
# #### Target Variable - Close value

# %% [markdown]
# ## TESLA

# %%
#Finding cross-correlation in data
plt.figure()
lag_plot(TSLA['Open'], lag=3)
plt.title('TESLA Stock - Autocorrelation plot with lag = 3')
plt.show()

# %% [markdown]
# #### there is auto-correlation in the data

# %%
plt.plot(TSLA["Date"], TSLA["Close"])
plt.xticks(np.arange(0,1259, 200), TSLA['Date'][0:1259:200])
plt.title("TESLA stock price over time")
plt.xlabel("time")
plt.ylabel("price")
plt.rcParams['figure.figsize'] = [10, 10]
plt.show()

# %% [markdown]
# Dividing data in 70:30
#
# p = 4, d =1, q=0

# %%
train_data, test_data = TSLA[0:int(len(TSLA)*0.7)], TSLA[int(len(TSLA)*0.7):]
training_data = train_data['Close'].values
test_data = test_data['Close'].values
history = [x for x in training_data]
model_predictions = []
N_test_observations = len(test_data)
for time_point in range(N_test_observations):
    model = ARIMA(history, order=(4,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    model_predictions.append(yhat)
    true_test_value = test_data[time_point]
    history.append(true_test_value)
MSE_error = mean_squared_error(test_data, model_predictions)
print('Testing Mean Squared Error is {}'.format(MSE_error))
# Out:
# Testing Mean Squared Error is 343.62078042623796

# %%
test_set_range = TSLA[int(len(TSLA)*0.7):].index
plt.plot(test_set_range, model_predictions, color='blue', marker='o', linestyle='dashed',label='Predicted Price')
plt.plot(test_set_range, test_data, color='red', label='Actual Price')
plt.title('TESLA Prices Prediction')
plt.xlabel('Date')
plt.ylabel('Prices')
plt.xticks(np.arange(881,1259,50), TSLA.Date[881:1259:50])
plt.rcParams['figure.figsize'] = [15, 15]
plt.legend()
plt.show()

# %% [markdown]
# ## GOOGLE

# %%
plt.figure()
lag_plot(GOOG['Open'], lag=3)
plt.title('Google Stock - Autocorrelation plot with lag = 3')
plt.show()

# %%
plt.plot(GOOG["Date"], GOOG["Close"])
plt.xticks(np.arange(0,1259, 200), GOOG['Date'][0:1259:200])
plt.title("Google stock price over time")
plt.xlabel("time")
plt.ylabel("price")
plt.rcParams['figure.figsize'] = [10, 10]
plt.show()

# %%
train_data, test_data = GOOG[0:int(len(GOOG)*0.7)], GOOG[int(len(GOOG)*0.7):]
training_data = train_data['Close'].values
test_data = test_data['Close'].values
history = [x for x in training_data]
model_predictions = []
N_test_observations = len(test_data)
for time_point in range(N_test_observations):
    model = ARIMA(history, order=(4,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    model_predictions.append(yhat)
    true_test_value = test_data[time_point]
    history.append(true_test_value)
MSE_error = mean_squared_error(test_data, model_predictions)
print('Testing Mean Squared Error is {}'.format(MSE_error))
# Out:
# Testing Mean Squared Error is 927.6988714546477

# %%
test_set_range = GOOG[int(len(GOOG)*0.7):].index
plt.plot(test_set_range, model_predictions, color='blue', marker='o', linestyle='dashed',label='Predicted Price')
plt.plot(test_set_range, test_data, color='red', label='Actual Price')
plt.title('Google Prices Prediction')
plt.xlabel('Date')
plt.ylabel('Prices')
plt.xticks(np.arange(881,1259,50), GOOG.Date[881:1259:50])
plt.rcParams['figure.figsize'] = [15, 15]
plt.legend()
plt.show()

# %% [markdown]
# ## AMAZON

# %%
plt.figure()
lag_plot(AMZN['Open'], lag=3)
plt.title('Amazon Stock - Autocorrelation plot with lag = 3')
plt.show()

# %%
plt.plot(AMZN["Date"], AMZN["Close"])
plt.xticks(np.arange(0,1259, 200), AMZN['Date'][0:1259:200])
plt.title("Amazon stock price over time")
plt.xlabel("time")
plt.ylabel("price")
plt.rcParams['figure.figsize'] = [10, 10]
plt.show()

# %%
train_data, test_data = AMZN[0:int(len(AMZN)*0.7)], AMZN[int(len(AMZN)*0.7):]
training_data = train_data['Close'].values
test_data = test_data['Close'].values
history = [x for x in training_data]
model_predictions = []
N_test_observations = len(test_data)
for time_point in range(N_test_observations):
    model = ARIMA(history, order=(4,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    model_predictions.append(yhat)
    true_test_value = test_data[time_point]
    history.append(true_test_value)
MSE_error = mean_squared_error(test_data, model_predictions)
print('Testing Mean Squared Error is {}'.format(MSE_error))
# Out:
# Testing Mean Squared Error is 2904.458060257267

# %%
test_set_range = AMZN[int(len(AMZN)*0.7):].index
plt.plot(test_set_range, model_predictions, color='blue', marker='o', linestyle='dashed',label='Predicted Price')
plt.plot(test_set_range, test_data, color='red', label='Actual Price')
plt.title('Amazon Prices Prediction')
plt.xlabel('Date')
plt.ylabel('Prices')
plt.xticks(np.arange(881,1259,50), AMZN.Date[881:1259:50])
plt.rcParams['figure.figsize'] = [15, 15]
plt.legend()
plt.show()
